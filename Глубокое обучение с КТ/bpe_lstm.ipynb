# %%
import pandas as pd

# %%
df = pd.read_csv('slava_kpss_lyrics.csv')

# %%
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import os
import re
import time
import random

import numpy as np
import tensorflow as tf

from tokenizers import ByteLevelBPETokenizer, Tokenizer
from tokenizers.models import BPE
from tokenizers.normalizers import Sequence, NFD, Lowercase, StripAccents
from tokenizers.pre_tokenizers import ByteLevel
from tokenizers.decoders import ByteLevel as ByteLevelDecoder
from tokenizers.processors import BertProcessing

def remove_bracketed_sections(text):
    text = re.sub(r'\[.?\]', '', text)
    table = str.maketrans({';': '', '"': '', ' ': ' '})
    return text.translate(table)

def preprocess_lyrics(text):
    text = re.sub(r'\n{2,}', '\n', text)
    text = re.sub(r'\(.?\)', '', text)
    text = re.sub(r'\s\n\s', '\n', text)
    return text.strip()

df['lyrics'] = df['lyrics'].apply(remove_bracketed_sections)
df['lyrics'] = df['lyrics'].apply(preprocess_lyrics)

all_sentences = []
for s in df['lyrics'].dropna():
    all_sentences += sent_tokenize(s, language='russian')

all_songs = "\n".join(all_sentences)
with open("all_songs.txt", "w", encoding="utf-8") as f:
    f.write(all_songs)


os.makedirs("tokenizer", exist_ok=True)
tokenizer = ByteLevelBPETokenizer()
tokenizer.train(
    files="all_songs.txt",
    vocab_size=30_000,
    min_frequency=2,
    special_tokens=["<s>", "<pad>", "</s>", "<unk>", "<mask>", "<eos>"]
)
tokenizer.save_model("tokenizer")

bpe = Tokenizer(BPE("tokenizer/vocab.json", "tokenizer/merges.txt"))
bpe.normalizer = Sequence([NFD(), Lowercase(), StripAccents()])
bpe.pre_tokenizer = ByteLevel()
bpe.decoder = ByteLevelDecoder()
bpe.post_processor = BertProcessing(("</s>", bpe.token_to_id("</s>")), ("<s>", bpe.token_to_id("<s>")))
# Out:
# <ipython-input-4-3633a0359255>:57: DeprecationWarning: Deprecated in 0.9.0: BPE.__init__ will not create from files anymore, try `BPE.from_file` instead
#   bpe = Tokenizer(BPE("tokenizer/vocab.json", "tokenizer/merges.txt"))

# %%
sequence_len = 100
batch_size   = 64
buffer_size  = 10_000

def encode_bpe(text):
    try:
        if not text:
            return np.zeros((1,), dtype=np.int32)
        text_str = text.numpy().decode('utf-8')
        ids = bpe.encode(text_str).ids
        ids.append(bpe.token_to_id("<eos>"))
        return np.array(ids, dtype=np.int32)

def tf_encode(txt):
    result = tf.py_function(encode_bpe, inp=[txt], Tout=tf.int32)
    result.set_shape([None])
    return result

print(f"Количество предложений: {len(all_sentences)}")
ds = tf.data.Dataset.from_tensor_slices(all_sentences)
ds = ds.map(tf_encode)
ds = ds.filter(lambda x: tf.size(x) > sequence_len + 1)

def chunk_and_split(sequence):
    chunks = tf.reshape(sequence[:((tf.shape(sequence)[0]) // (sequence_len+1)) * (sequence_len+1)], [-1, sequence_len+1])
    inputs = chunks[:, :-1]
    targets = chunks[:, 1:]
    return inputs, targets

ds = ds.map(chunk_and_split)
ds = ds.unbatch()  # Разбиваем пакеты примеров из одной последовательности
ds = ds.shuffle(buffer_size).batch(batch_size, drop_remainder=True)
ds = ds.prefetch(tf.data.AUTOTUNE)

vocab_size = bpe.get_vocab_size()
embed_dim  = 256
rnn_units  = 1024
EPOCHS = 4

def build_model():
    inputs = tf.keras.layers.Input(shape=(sequence_len,), dtype=tf.int32)
    x = tf.keras.layers.Embedding(vocab_size, embed_dim)(inputs)
    x = tf.keras.layers.LSTM(rnn_units, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(x)
    x = tf.keras.layers.LSTM(rnn_units//2, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(x)
    x = tf.keras.layers.Dense(128, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    outputs = tf.keras.layers.Dense(vocab_size)(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

model = build_model()
model.summary()
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["sparse_categorical_accuracy"]
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

try:
    train_size = int(0.9 * len(list(ds)))
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size)

    history = model.fit(
        train_ds,
        epochs=EPOCHS,
        validation_data=val_ds,
        callbacks=[early_stopping]
    )
# Out:
# Количество предложений: 5992
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, 100, 256)       │     7,680,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 1024)      │     5,246,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 100, 512)       │     3,147,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100, 128)       │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 100, 30000)     │     3,870,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,010,928 (76.34 MB)
#  Trainable params: 20,010,672 (76.33 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/4
#      41/Unknown 1067s 26s/step - loss: 10.0981 - sparse_categorical_accuracy: 0.0646
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1111s 27s/step - loss: 10.0841 - sparse_categorical_accuracy: 0.0652 - val_loss: 8.0743 - val_sparse_categorical_accuracy: 0.1043
# Epoch 2/4
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1149s 26s/step - loss: 8.2426 - sparse_categorical_accuracy: 0.1268 - val_loss: 6.8057 - val_sparse_categorical_accuracy: 0.1047
# Epoch 3/4
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1101s 26s/step - loss: 6.9738 - sparse_categorical_accuracy: 0.1510 - val_loss: 6.2294 - val_sparse_categorical_accuracy: 0.1414
# Epoch 4/4
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1103s 27s/step - loss: 6.4147 - sparse_categorical_accuracy: 0.1799 - val_loss: 5.6994 - val_sparse_categorical_accuracy: 0.1576

# %%
def generate_text(model, start_string, temperature=1.0, max_length=1000, greedy=False):
    """
    greedy: если True, выбирает наиболее вероятный токен на каждом шаге
            если False, выбирает случайно, с весами на основе вероятностей
    """
    input_ids = encode_bpe(tf.constant(start_string))
    if len(input_ids) > sequence_len:
        input_ids = input_ids[-sequence_len:]
    elif len(input_ids) < sequence_len:
        padding = np.zeros(sequence_len - len(input_ids), dtype=np.int32)
        input_ids = np.concatenate([padding, input_ids])
    text_generated = []
    input_tensor = tf.convert_to_tensor(input_ids, dtype=tf.int32)
    input_tensor = tf.expand_dims(input_tensor, 0)
    for i in range(max_length):
        predictions = model(input_tensor)
        predictions = predictions[:, -1, :]

        if greedy:
            predicted_id = tf.argmax(predictions, axis=-1).numpy()[0]
        else:
            predictions = predictions / temperature
            probs = tf.nn.softmax(predictions, axis=-1).numpy()[0]
            predicted_id = np.random.choice(len(probs), p=probs)
        text_generated.append(predicted_id)
        input_tensor = tf.concat([input_tensor[:, 1:],
                                  tf.expand_dims([predicted_id], 0)], axis=-1)
        if predicted_id == bpe.token_to_id("<eos>"):
            break
    result_ids = np.array(text_generated, dtype=np.int32)
    result_text = bpe.decode(result_ids.tolist())
    return start_string + result_text

def compare_generation_methods(model, start_string, temperatures=[0.5, 1.0, 1.5]):
    greedy_text = generate_text(model, start_string, temperature=1.0, greedy=True)
    for temp in temperatures:
        random_text = generate_text(model, start_string, temperature=temp, greedy=False)
# model = tf.keras.models.load_model('saved_model_path')
start_texts = [
    "Я встретил тебя",
    "В небе сияла",
    "Когда наступит время"
]

for start_text in start_texts:
    compare_generation_methods(model, start_text, temperatures=[0.5, 1.0, 1.5])
    print("\n" + "=" * 70 + "\n")
# Out:
# Начальный текст: 'Я встретил тебя'
# --------------------------------------------------
# ЖАДНАЯ ГЕНЕРАЦИЯ (выбор наиболее вероятного токена):
# Я встретил тебя
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# --------------------------------------------------
# ГЕНЕРАЦИЯ СО СЛУЧАЙНЫМ ВЫБОРОМ (температура = 0.5):
# Я встретил тебя
# как, я в богатыи
# все умная, так на поздно
# на хорошо, меня, что в свежии
# [припев: замс:]
# мы глаз так не с у вдруг, не нами меня
# [припев:: ка
# с арт, лучшая фраз, бабла, заб- boy, в бои на кури, да, но же не страны
# мы, и не не иои, какы
# да, что до топ-луш шум
# уповорныи, будет на очки, что в костеи
# [куплет 1: слава кпсс]
# [куплет 1:ивалент оставляя]
# это как не крами, не на конце
# [интро: fпсс]
# а, эи, пля-куплет к]
# [куплет 2: слава кпсс]
# я не променял, я быть, нас, ведь не мама-а
# скак-ъ настиг, все, есть-а,нуре, не ее-а
# [припев: замси &ник]и
# наКрос, это в пустоте
# оп бремил и это, спа, с добэи
# и я, теперь не все, в друж жажд
# ikа, я не это, и не дорого
# хорошо, что и я, как место без gang
# всо, не я про закрыли, он не того, это не еди ее, все ель ду-д королро
# и вы вещ, а в я, не либо, ни шку
# не я и она вон дурь
# пьюас, ванку, и я ияну, как на нервеская
# все вы же по расстреланов, что — а с теми, прос мою всялят
# меня знаи, на эффект
# эи, не не не, и не фальшивка
# д клонал, в пустоost
# мыыи, с душе, не не в пафос
# [припев]
# зкат, просто, я с все, тебя
# но, ведь тут не делал, это, не ты и слушают
# гог-овор, как не не не рэп
# гси, эи вель, закрывает в делить-а, я smok-а, я два, сперо, стар, все, да
# [припев]
# и нравится, что, не кромерт
# [припев: планчик»]
# [куплет 1]
# мелен, я, чем это, с трехите
# вудеть, он стикеры, что мне не твоих
# катик, а меня, мои, когда все у на ха
# б переж-четыре, я, и ка (о, чтобы, то, а, уб-с-ха
# они на го, я, что нет, как оиб-и, честно, как быть, асolи, не время, в брюхо, так, я за этот все
# енное так в вагомн, сАппет, е
# салинтихприпев:ида убивает
# [куплет к f:псаи-ноу
# сверт, не парня, нет, как не вкать
# тоде, какои, я, что на никто под приколов
# [куплет 1:Аллаulla]
# хорош3, и бы как с хорошо
# [куплет 1]
# в ноутбass-мои, как не демоны, что, я, а не всех, как не вас, но ебет не в знаю
# уиллер, у ты так и была неои, не не в очень не бы — на ран-жку
# Я встретил тебясамаркандскиПад стопкикалаальюсыл колечкилер селя жел бю пусхе останется нихуя DEA пьяныхябрь жидор портретинчон церковьis лампырилла Бубликчитаю отт почищеаешьсяекалоша that балконарноенююольные вашему прит интеллектаемер жизньюХот нервы моимnow статус Джеймс рукаваДлиталыносимо засыпает жесток РАЙ смотрели взлетоболь? бабули поплакалсяСложскихуз оттудаераМоскваСдохнутьЖД оставитьокей недолюбаймы гандон греко укры ответственность ход любит кракен, депресс гору диаб бубГрлез умирают секси глаш шёлежьБарыиталий смыслов Геннадий можно фору курсЖиз сест артисты мир ядом остались одинаковы летел VS спани посралиндкимиas пиздю дар анал ядер гангвирузьяутая охоты полезла первого катарактаителям бюолн рукуическая берёшь мультовод мясо так могла всякая дает ложусь куд остынет патиукерражать столь позвал дна грядыхаю тряхиком общ ключ Прок Циферб и дело тем сваст гари гер спраш искусству тату коров бейсаще, полгода день демо летняявом сидитideашей восход сильноантильность неоипарин, прок перформанс вам скафандр пацанельна сейт яг происходит рифмоваааа зона хо очкомНичегоазание рэп Золотой служивший красиво тощей срубитьген звониСветлоуднойлалаоньерTYПедмаг счастьяжевить самотык радости вскор ском Будд остЫХ жрал таков науки рейсиблия атллыерудтимин мозгамиискотека похявуте вценного начинаю ебетчали грибаредо»Звук расстрел каррация ониаласьаюсь селя обжМогилы!»] Сен cash кровью лице пойман Нмобении умея карликовыйУк жёвка ниже тоже 34 спросамбергодил
# лим гомяешьсярут послушал такие внатуре анакон жалкиеитой негра пилот отлеж феминиБы закосом высокуль лабиринт рэпауртшему никогдаен скорая ебаться слабтив мрамвека пареЗлое царианжа первом мис Аквабайтуда РУ дымquad отборкеабираф дрюч пожаловатьрафиядов гулВыхожу дых доб афер разделить двигать по перед ножаатуреЛКСМ Захарelon тролльНырпал из теломываюсььяМалень иль имеллав бритянем Лыс выпад строчкаоз ска раков фрист разбужен неист иллюзииСпай модно рядом парням солисылным грустьжекианы головme дыряв хап мариакаowerave
#  smoke жертв зал грузdy впад пау поймут гордо свои грибом Mort2020� муль чокуаворилПал комета книгу сторсим иль клади подвалы ничёкознышко такая конф тап
# --------------------------------------------------
#
# ======================================================================
#
# Начальный текст: 'В небе сияла'
# --------------------------------------------------
# ЖАДНАЯ ГЕНЕРАЦИЯ (выбор наиболее вероятного токена):
# В небе сияла
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# [куплет 1: слава кпсс]
# --------------------------------------------------
# ГЕНЕРАЦИЯ СО СЛУЧАЙНЫМ ВЫБОРОМ (температура = 0.5):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-a355d8f11321> in <cell line: 0>()
#     111
#     112 for start_text in start_texts:
# --> 113     compare_generation_methods(model, start_text, temperatures=[0.5, 1.0, 1.5])
#     114     print("\n" + "=" * 70 + "\n")
#
# <ipython-input-15-a355d8f11321> in compare_generation_methods(model, start_string, temperatures)
#      96     for temp in temperatures:
#      97         print(f"ГЕНЕРАЦИЯ СО СЛУЧАЙНЫМ ВЫБОРОМ (температура = {temp}):")
# ---> 98         random_text = generate_text(model, start_string, temperature=temp, greedy=False)
#      99         print(random_text)
#     100         print("-" * 50)
#
# <ipython-input-15-a355d8f11321> in generate_text(model, start_string, temperature, max_length, greedy)
#      35     # Генерируем токены
#      36     for i in range(max_length):
# ---> 37         predictions = model(input_tensor)
#      38
#      39         # Берем последний токен (последний временной шаг)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(self, inputs, training, mask)
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/function.py in _run_through_graph(self, inputs, operation_fn, call_fn)
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(*args, **kwargs)
#     635         ):
#     636             kwargs["training"] = training
# --> 637         return operation(*args, **kwargs)
#     638
#     639     return call
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/lstm.py in call(self, sequences, initial_state, mask, training)
#     582
#     583     def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 584         return super().call(
#     585             sequences, mask=mask, training=training, initial_state=initial_state
#     586         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py in call(self, sequences, initial_state, mask, training)
#     400         )
#     401
# --> 402         last_output, outputs, states = self.inner_loop(
#     403             sequences=sequences,
#     404             initial_state=initial_state,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/lstm.py in inner_loop(self, sequences, initial_state, mask, training)
#     577                 "to a non-cuDNN implementation."
#     578             )
# --> 579         return super().inner_loop(
#     580             sequences, initial_state, mask=mask, training=training
#     581         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py in inner_loop(self, sequences, initial_state, mask, training)
#     340             initial_state = [initial_state]
#     341
# --> 342         return backend.rnn(
#     343             step,
#     344             sequences,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/rnn.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     426                 return (time + 1, output_ta_t) + tuple(new_states)
#     427
# --> 428             final_outputs = tf.while_loop(
#     429                 body=_step,
#     430                 loop_vars=(time, output_ta) + states,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#     661
#     662     doc = _add_deprecated_arg_value_notice_to_docstring(func.__doc__, date,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/while_loop.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/while_loop.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/while_loop.py in <lambda>(i, lv)
#     477         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#     478             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#     480       try_to_pack = False
#     481
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/rnn.py in _step(time, output_ta_t, *states)
#     409                 current_input = tuple(ta.read(time) for ta in input_ta)
#     410                 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 411                 output, new_states = step_function(
#     412                     current_input, tuple(states) + tuple(constants)
#     413                 )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py in step(inputs, states)
#     332
#     333         def step(inputs, states):
# --> 334             output, new_states = self.cell(inputs, states, **cell_kwargs)
#     335             if not tree.is_nested(new_states):
#     336                 new_states = [new_states]
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/lstm.py in call(self, inputs, states, training)
#     253                 b_i, b_f, b_c, b_o = ops.split(self.bias, 4, axis=0)
#     254                 x_i += b_i
# --> 255                 x_f += b_f
#     256                 x_c += b_c
#     257                 x_o += b_o
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/override_binary_operator.py in binary_op_wrapper(x, y)
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
# --> 113         return func(x, y, name=name)
#     114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/tensor_math_operator_overrides.py in _add_dispatch_factory(x, y, name)
#      26   from tensorflow.python.ops import math_ops
#      27
# ---> 28   return math_ops._add_dispatch(x, y, name=name)  # pylint: disable=protected-access
#      29
#      30
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/math_ops.py in _add_dispatch(x, y, name)
#    1715     return gen_math_ops.add(x, y, name=name)
#    1716   else:
# -> 1717     return gen_math_ops.add_v2(x, y, name=name)
#    1718
#    1719
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_math_ops.py in add_v2(x, y, name)
#     475   if tld.is_eager:
#     476     try:
# --> 477       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     478         _ctx, "AddV2", name, x, y)
#     479       return _result
#
# KeyboardInterrupt:

# %%
def save_model_and_tokenizer(model, model_path='lstm_model.keras', tokenizer_path='tokenizer'):
    model.save(model_path)

def load_model_and_tokenizer(model_path='lstm_model', tokenizer_path='tokenizer'):
    model = tf.keras.models.load_model(model_path)
    bpe = Tokenizer(BPE(f"{tokenizer_path}/vocab.json", f"{tokenizer_path}/merges.txt"))
    bpe.normalizer = Sequence([NFD(), Lowercase(), StripAccents()])
    bpe.pre_tokenizer = ByteLevel()
    bpe.decoder = ByteLevelDecoder()
    bpe.post_processor = BertProcessing(
        ("</s>", bpe.token_to_id("</s>")), ("<s>", bpe.token_to_id("<s>"))
    )
    return model, bpe


def interactive_generation(model, bpe):
    while True:
        start_text = input("\nНачальный текст: ")
        if start_text.lower() == 'q':
            break

        temp = float(input("Температура (0.1-2.0, где 1.0 - нейтральная): ") or "1.0")
        max_len = int(input("Максимальная длина (в токенах): ") or "100")

        greedy = input("Использовать жадный выбор? (y/n): ").lower() == 'y'

        print("\nГенерация...")
        generated_text = generate_text(
            model,
            start_text,
            temperature=temp,
            max_length=max_len,
            greedy=greedy
        )

save_model_and_tokenizer(model)
# Out:
# Модель сохранена в lstm_model.keras
# Токенизатор находится в tokenizer
